# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from helper import visualize

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### Dataset

# %%
df = pd.read_csv('data/in_context_responses.csv', lineterminator='\n').drop(columns=['Unnamed: 0'])
df.head(10)
# Out:
#         user_id candidate hashtag  score_topic_0  score_topic_1  \
# 0  1.864362e+09     trump   biden            5.0            3.0
# 1  1.132466e+18     biden   biden            3.0            4.0
# 2  2.739945e+09       NaN   biden            NaN            NaN
# 3  5.937695e+08     biden   biden            5.0            4.0
# 4  1.174653e+18     biden   biden            5.0            4.0
# 5  2.388516e+09     biden   biden            1.0            3.0
# 6  1.006104e+18     biden   biden            3.0            4.0
# 7  1.624188e+07     biden   biden            3.0            5.0
# 8  1.138512e+09     biden   biden            1.0            5.0
# 9  6.118990e+07     biden   biden            5.0            4.0
#
#    score_topic_2  score_topic_3  score_topic_4  score_topic_5  score_topic_6  \
# 0            2.0            4.0            3.0            2.0            4.0
# 1            5.0            5.0            4.0            5.0            1.0
# 2            NaN            NaN            NaN            NaN            NaN
# 3            5.0            5.0            4.0            5.0            1.0
# 4            5.0            5.0            4.0            5.0            1.0
# 5            5.0            4.0            2.0            5.0            2.0
# 6            5.0            5.0            4.0            5.0            2.0
# 7            5.0            5.0            3.0            5.0            3.0
# 8            5.0            5.0            5.0            5.0            5.0
# 9            5.0            4.0            3.0            5.0            3.0
#
#    score_topic_7  score_topic_8  score_topic_9
# 0            5.0            4.0            3.0
# 1            5.0            5.0            5.0
# 2            NaN            NaN            NaN
# 3            5.0            5.0            5.0
# 4            5.0            5.0            5.0
# 5            5.0            5.0            4.0
# 6            5.0            5.0            5.0
# 7            5.0            5.0            5.0
# 8            1.0            5.0            5.0
# 9            5.0            5.0            5.0

# %%
df = df.dropna(how='any')
df.shape
# Out:
# (94, 13)

# %% [markdown]
# ### Questions
#
# Please share your level of agreement with \_\_\_topic___. (score 1-5)

# %%
topics = [
    'allowing transgender athletes',
    'gun control',
    'abortion legalization',
    'the universities practicing affirmative action',
    'raising fossil fuel taxes',
    'helping undocumented immigrants',
    'death penalty in the US',
    'allowing women to serve in military combat roles',
    'legalization of Marijuana',
    'reducing interest rates for student loans'
]
topics = pd.Series(topics)
topics
# Out:
# 0                       allowing transgender athletes
# 1                                         gun control
# 2                               abortion legalization
# 3      the universities practicing affirmative action
# 4                           raising fossil fuel taxes
# 5                     helping undocumented immigrants
# 6                             death penalty in the US
# 7    allowing women to serve in military combat roles
# 8                           legalization of Marijuana
# 9           reducing interest rates for student loans
# dtype: object

# %% [markdown]
# ## Overview

# %% [markdown]
# Counting the supporters of Biden and Trump

# %%
sns.countplot(data=df, x='candidate', palette=['red','blue'])
# Out:
# <AxesSubplot:xlabel='candidate', ylabel='count'>

# %% [markdown]
# ## Allowing transgender athletes?

# %%
for i in range(len(topics)):
    question_No = i
    visualize(df, question_No, topics)
